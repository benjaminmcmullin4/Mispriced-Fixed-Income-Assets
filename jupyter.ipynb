# %%
import pandas as pd

# %%
macro_and_bond_data = pd.read_csv("data/macro_and_bond_data.csv")
#cclean_data = pd.read_csv("data/cleaned_macro_data.csv")

# %%
macro_and_bond_data.head()
# Out:
#          date  2Y_Treasury_Yield  5Y_Treasury_Yield  10Y_Treasury_Yield  \
# 0  1980-01-01              11.75              11.11               11.13
# 1  1980-01-01              11.75              11.11               11.13
# 2  1980-01-01              11.75              11.11               11.13
# 3  1980-01-01              11.75              11.11               11.13
# 4  1980-01-01              11.75              11.11               11.13
#
#    30Y_Treasury_Yield  Fed_Funds_Rate  Overnight_Repo_Rate   CPI  Core_CPI  \
# 0               11.09           13.82                  NaN  78.0      76.7
# 1               11.09           13.82                  NaN  78.0      76.7
# 2               11.09           13.82                  NaN  78.0      76.7
# 3               11.09           13.82                  NaN  78.0      76.7
# 4               11.09           13.82                  NaN  78.0      76.7
#
#    PCE_Inflation  ...  Retail_Sales  USD_EUR_Exchange_Rate        Date   ^TNX  \
# ...
